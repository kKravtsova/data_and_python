# %% [markdown]
# <a href="https://colab.research.google.com/github/kKravtsova/data_and_python/blob/main/Normalising_challenges_kkravtsova.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Normalisation challenges

# %% [markdown]
# ### Challenge 1 - prepare dataset for normalisation
# ---
# 1. Read Covid vaccination data from the `by_country` sheet in the Excel file at this link : https://github.com/lilaceri/Working-with-data-/blob/342abab10d93c4bf23b5c55a50f189f12a137c5f/Data%20Sets%20for%20code%20divisio/Covid%20Vaccination%20Data.xlsx?raw=true
# 2. Use .info() to find out which columns have missing values
# 3. Remove all rows with missing data in the total_vaccination column
# 4. Find the median vaccinations per hundred
# 5. display the mean people vaccinated per hundred for each country in descending order
# 6. find the range of total_vaccinations across the dataframe
#
#
# **Test output**:
# 1. dataframe is saved in a variable
# 2.
# ```
# RangeIndex: 14994 entries, 0 to 14993
# Data columns (total 15 columns):
#     Column                               Non-Null Count  Dtype
#
#  0   country                              14994 non-null  object
#  1   iso_code                             14994 non-null  object
#  2   date                                 14994 non-null  datetime64[ns]
#  3   total_vaccinations                   9011 non-null   float64
#  4   people_vaccinated                    8370 non-null   float64
#  5   people_fully_vaccinated              6158 non-null   float64
#  6   daily_vaccinations_raw               7575 non-null   float64
#  7   daily_vaccinations                   14796 non-null  float64
#  8   total_vaccinations_per_hundred       9011 non-null   float64
#  9   people_vaccinated_per_hundred        8370 non-null   float64
#  10  people_fully_vaccinated_per_hundred  6158 non-null   float64
#  11  daily_vaccinations_per_million       14796 non-null  float64
#  12  vaccines                             14994 non-null  object
#  13  source_name                          14994 non-null  object
#  14  source_website                       14994 non-null  object
# dtypes: datetime64[ns](1), float64(9), object(5)
# memory usage: 1.7+ MB
# ```
# 3. 9011 rows × 15 columns
# 4. 7.78
# 5.
# ```
# country
# Gibraltar       72.172462
# Maldives        51.276087
# Israel          48.931008
# Seychelles      48.233333
# Aruba           42.155000
#                   ...
# Guinea           0.677000
# Sierra Leone     0.530000
# Namibia          0.317143
# South Africa     0.261667
# Albania          0.080000
# Name: people_vaccinated_per_hundred, Length: 104, dtype: float64
# ```
# 6. 275338000.0

# %%
# Read Covid vaccination data from the by_country sheet in the Excel file at this link
import pandas as pd
import numpy as np

url = "https://github.com/lilaceri/Working-with-data-/blob/342abab10d93c4bf23b5c55a50f189f12a137c5f/Data%20Sets%20for%20code%20divisio/Covid%20Vaccination%20Data.xlsx?raw=true"
vac_df = pd.read_excel(url, sheet_name = "by_country")
vac_df.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0
#
#              vaccines                source_name  \
# 0  Oxford/AstraZeneca  Government of Afghanistan
# 1  Oxford/AstraZeneca  Government of Afghanistan
# 2  Oxford/AstraZeneca  Government of Afghanistan
# 3  Oxford/AstraZeneca  Government of Afghanistan
# 4  Oxford/AstraZeneca  Government of Afghanistan
#
#                                       source_website
# 0  https://reliefweb.int/report/afghanistan/afgha...
# 1  https://reliefweb.int/report/afghanistan/afgha...
# 2  https://reliefweb.int/report/afghanistan/afgha...
# 3  https://reliefweb.int/report/afghanistan/afgha...
# 4  https://reliefweb.int/report/afghanistan/afgha...

# %%
# Use .info() to find out which columns have missing values
vac_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14994 entries, 0 to 14993
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              14994 non-null  object
#  1   iso_code                             14994 non-null  object
#  2   date                                 14994 non-null  datetime64[ns]
#  3   total_vaccinations                   9011 non-null   float64
#  4   people_vaccinated                    8370 non-null   float64
#  5   people_fully_vaccinated              6158 non-null   float64
#  6   daily_vaccinations_raw               7575 non-null   float64
#  7   daily_vaccinations                   14796 non-null  float64
#  8   total_vaccinations_per_hundred       9011 non-null   float64
#  9   people_vaccinated_per_hundred        8370 non-null   float64
#  10  people_fully_vaccinated_per_hundred  6158 non-null   float64
#  11  daily_vaccinations_per_million       14796 non-null  float64
#  12  vaccines                             14994 non-null  object
#  13  source_name                          14994 non-null  object
#  14  source_website                       14994 non-null  object
# dtypes: datetime64[ns](1), float64(9), object(5)
# memory usage: 1.7+ MB

# %%
# Remove all rows with missing data in the total_vaccination column
vac_df.dropna(subset = ["total_vaccinations"])
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG 2021-02-22                 0.0                0.0
# 6      Afghanistan      AFG 2021-02-28              8200.0             8200.0
# 22     Afghanistan      AFG 2021-03-16             54000.0            54000.0
# 44     Afghanistan      AFG 2021-04-07            120000.0           120000.0
# 59     Afghanistan      AFG 2021-04-22            240000.0           240000.0
# ...            ...      ...        ...                 ...                ...
# 14989     Zimbabwe      ZWE 2021-04-28            458013.0           388021.0
# 14990     Zimbabwe      ZWE 2021-04-29            477597.0           400771.0
# 14991     Zimbabwe      ZWE 2021-04-30            500342.0           414735.0
# 14992     Zimbabwe      ZWE 2021-05-01            520299.0           428135.0
# 14993     Zimbabwe      ZWE 2021-05-02            524199.0           430068.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                          NaN                     NaN                 NaN
# 6                          NaN                     NaN              1367.0
# 22                         NaN                     NaN              2862.0
# 44                         NaN                     NaN              3000.0
# 59                         NaN                     NaN              8000.0
# ...                        ...                     ...                 ...
# 14989                  69992.0                 24074.0             17860.0
# 14990                  76826.0                 19584.0             17971.0
# 14991                  85607.0                 22745.0             19194.0
# 14992                  92164.0                 19957.0             21171.0
# 14993                  94131.0                  3900.0             19169.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                                0.00                           0.00
# 6                                0.02                           0.02
# 22                               0.14                           0.14
# 44                               0.31                           0.31
# 59                               0.62                           0.62
# ...                               ...                            ...
# 14989                            3.08                           2.61
# 14990                            3.21                           2.70
# 14991                            3.37                           2.79
# 14992                            3.50                           2.88
# 14993                            3.53                           2.89
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                      NaN                             NaN
# 6                                      NaN                            35.0
# 22                                     NaN                            74.0
# 44                                     NaN                            77.0
# 59                                     NaN                           206.0
# ...                                    ...                             ...
# 14989                                 0.47                          1202.0
# 14990                                 0.52                          1209.0
# 14991                                 0.58                          1291.0
# 14992                                 0.62                          1424.0
# 14993                                 0.63                          1290.0
#
#                  vaccines                source_name  \
# 0      Oxford/AstraZeneca  Government of Afghanistan
# 6      Oxford/AstraZeneca  Government of Afghanistan
# 22     Oxford/AstraZeneca  Government of Afghanistan
# 44     Oxford/AstraZeneca  Government of Afghanistan
# 59     Oxford/AstraZeneca  Government of Afghanistan
# ...                   ...                        ...
# 14989   Sinopharm/Beijing         Ministry of Health
# 14990   Sinopharm/Beijing         Ministry of Health
# 14991   Sinopharm/Beijing         Ministry of Health
# 14992   Sinopharm/Beijing         Ministry of Health
# 14993   Sinopharm/Beijing         Ministry of Health
#
#                                           source_website
# 0      https://reliefweb.int/report/afghanistan/afgha...
# 6      https://reliefweb.int/report/afghanistan/afgha...
# 22     https://reliefweb.int/report/afghanistan/afgha...
# 44     https://reliefweb.int/report/afghanistan/afgha...
# 59     https://reliefweb.int/report/afghanistan/afgha...
# ...                                                  ...
# 14989  https://twitter.com/MoHCCZim/status/1388935941...
# 14990  https://twitter.com/MoHCCZim/status/1388935941...
# 14991  https://twitter.com/MoHCCZim/status/1388935941...
# 14992  https://twitter.com/MoHCCZim/status/1388935941...
# 14993  https://twitter.com/MoHCCZim/status/1388935941...
#
# [9011 rows x 15 columns]

# %%
vac_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14994 entries, 0 to 14993
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              14994 non-null  object
#  1   iso_code                             14994 non-null  object
#  2   date                                 14994 non-null  datetime64[ns]
#  3   total_vaccinations                   9011 non-null   float64
#  4   people_vaccinated                    8370 non-null   float64
#  5   people_fully_vaccinated              6158 non-null   float64
#  6   daily_vaccinations_raw               7575 non-null   float64
#  7   daily_vaccinations                   14796 non-null  float64
#  8   total_vaccinations_per_hundred       9011 non-null   float64
#  9   people_vaccinated_per_hundred        8370 non-null   float64
#  10  people_fully_vaccinated_per_hundred  6158 non-null   float64
#  11  daily_vaccinations_per_million       14796 non-null  float64
#  12  vaccines                             14994 non-null  object
#  13  source_name                          14994 non-null  object
#  14  source_website                       14994 non-null  object
# dtypes: datetime64[ns](1), float64(9), object(5)
# memory usage: 1.7+ MB

# %%
# vac_df.dropna()

# %%
# Find the median vaccinations per hundred
vac_df["total_vaccinations_per_hundred"].median()
# Out:
# 6.3

# %%
# display the mean people vaccinated per hundred for each country in descending order
mpv_df = vac_df.groupby(["country"])["people_vaccinated_per_hundred"].mean().sort_values(ascending = False)

# %%
mpv_df.to_frame()
# Out:
#                                   people_vaccinated_per_hundred
# country
# Gibraltar                                             64.975699
# Bhutan                                                55.961892
# Falkland Islands                                      51.063333
# Saint Helena                                          44.880000
# Seychelles                                            44.005686
# ...                                                         ...
# China                                                       NaN
# Ethiopia                                                    NaN
# Saint Vincent and the Grenadines                            NaN
# Samoa                                                       NaN
# Saudi Arabia                                                NaN
#
# [195 rows x 1 columns]

# %%
# find the range of total_vaccinations across the dataframe
tot_vac_min = vac_df["total_vaccinations"].min()
tot_vac_max = vac_df["total_vaccinations"].max()
tot_range = tot_vac_max - tot_vac_min
tot_range
# Out:
# 275338000.0

# %% [markdown]
# ### Challenge 2 - normalise daily vaccinations
# ---
#
# 1. Find the median daily vaccinations per million
# 2. Write a function to normalise daily vaccinations per million, where values greater than or equal to median = 1 and values less than median = 0
#
# **Test output**:
#
# 1. 1475.0
# 2. using describe()
# ```
# count    14994.000000
# mean         0.493464
# std          0.499974
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: daily_vaccinations_per_million, dtype: float64
# ```

# %%
vac_df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        9.011000e+03       8.370000e+03             6.158000e+03
# mean         4.964584e+06       3.164030e+06             1.580482e+06
# std          2.033452e+07       1.180919e+07             6.840161e+06
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          6.000000e+04       5.154925e+04             2.350025e+04
# 50%          4.209400e+05       3.255035e+05             1.729175e+05
# 75%          1.932222e+06       1.338161e+06             6.887102e+05
# max          2.753380e+08       1.470470e+08             1.047747e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            7.575000e+03        1.479600e+04
# mean             1.347569e+05        7.769163e+04
# std              5.211912e+05        3.519679e+05
# min              0.000000e+00        0.000000e+00
# 25%              2.888500e+03        8.967500e+02
# 50%              1.558300e+04        6.178500e+03
# 75%              6.249850e+04        2.835000e+04
# max              1.160100e+07        7.205286e+06
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                     9011.000000                    8370.000000
# mean                        15.456079                      11.228710
# std                         23.238675                      15.269686
# min                          0.000000                       0.000000
# 25%                          1.330000                       1.222500
# 50%                          6.300000                       4.825000
# 75%                         19.570000                      14.667500
# max                        211.080000                     111.320000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                           6158.00000                    14796.000000
# mean                               5.66235                     2972.163625
# std                               10.06184                     4720.846894
# min                                0.00000                        0.000000
# 25%                                0.63000                      347.000000
# 50%                                2.35000                     1475.000000
# 75%                                6.30000                     3908.250000
# max                               99.76000                   118759.000000

# %%
# Find the median daily vaccinations per million
med = vac_df["daily_vaccinations_per_million"].median()
med
# Out:
# 1475.0

# %%
# Write a function to normalise daily vaccinations per million,
# where values greater than or equal to median = 1 and values less than median = 0
def norm_daily_vac(df):
  if df["daily_vaccinations_per_million"] >= med:
    return 1
  else:
    return 0

vac_df["daily_vaccinations_per_million"] = vac_df.apply(norm_daily_vac, axis=1)

# %%
vac_df["daily_vaccinations_per_million"].max()
# Out:
# 1

# %%
vac_df["daily_vaccinations_per_million"].min()
# Out:
# 0

# %% [markdown]
# ### Challenge 3 - Normalising total vaccinations
# ---
# The United Kingdom has been praised for its fast vaccine rollout.
# 1. Find the minimum total vaccinations for the United Kingdom
# 2. Save this value in a variable rounded down to an integer
# 3. Write a function to normalise total_vaccinations column so that all values less than the UK's min are 0 and all values greater than or equal to the UK's min are coded as 1
# 4. Display the countries for which total vaccinated is at the same rate or more than the UK
#
# **Test output**:
#
# 1. 1402432.0
# 2. 1402432
# 3. `df['total_vaccinations']` should output:
# ```
# 0        0
# 6        0
# 22       0
# 44       0
# 59       0
#         ..
# 14989    0
# 14990    0
# 14991    0
# 14992    0
# 14993    0
# Name: total_vaccinations, Length: 9011, dtype: int64
# ```
# 4.
# ```
# array(['Argentina', 'Australia', 'Austria', 'Azerbaijan', 'Bangladesh',
#        'Belgium', 'Brazil', 'Cambodia', 'Canada', 'Chile', 'China',
#        'Colombia', 'Czechia', 'Denmark', 'Dominican Republic', 'England',
#        'Finland', 'France', 'Germany', 'Greece', 'Hong Kong', 'Hungary',
#        'India', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan',
#        'Kazakhstan', 'Malaysia', 'Mexico', 'Morocco', 'Nepal',
#        'Netherlands', 'Norway', 'Pakistan', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Saudi Arabia',
#        'Scotland', 'Serbia', 'Singapore', 'Slovakia', 'South Korea',
#        'Spain', 'Sweden', 'Switzerland', 'Thailand', 'Turkey',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Wales'], dtype=object)
# ```

# %%
# Find the minimum total vaccinations for the United Kingdom
min_UK = vac_df[vac_df["country"] == "United Kingdom"]["total_vaccinations"].min()
min_UK
# Out:
# 1402432.0

# %%
# Save this value in a variable rounded down to an integer
min_UK = int(min_UK)
min_UK
# Out:
# 1402432

# %%
# Write a function to normalise total_vaccinations column so that all values less than the UK's min are 0
# and all values greater than or equal to the UK's min are coded as 1
def norm_tot_vac(df):
  if df["total_vaccinations"] < min_UK:
    return 1
  else:
    return 0

vac_df["total_vaccinations"] = vac_df.apply(norm_tot_vac, axis=1)

# %%
vac_df["total_vaccinations"].max()
# Out:
# 1

# %%
vac_df["total_vaccinations"].min()
# Out:
# 0

# %%
vac_df['total_vaccinations'].to_frame()
# Out:
#        total_vaccinations
# 0                       1
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 14989                   1
# 14990                   1
# 14991                   1
# 14992                   1
# 14993                   1
#
# [14994 rows x 1 columns]

# %%
# Display the countries for which total vaccinated is at the same rate or more than the UK

# %% [markdown]
# ### Challenge 4 - create new series of total vaccinations for each manufacturer
# ---
#
# To create a new column in your dataframe:
#
# `df['new_column'] = ...`
#
# For example:
#
# * to duplicate an existing column
#   * `df['new_column'] = df['old_column']`
# * to add two columns together
#   * `df['new_column'] = df['column1'] + df['column2']`
# * to make a percentages column
#   * `df['new_column'] = (df['column1']/df['column1].sum()) * 100`
#
#
# 1. read data from 'by_manufacturer' sheet from Covid data
# 2. find the sum of total vaccinations for each manufacturer
# 3. create a new column that has the total vaccinations as a percentage of the overall sum of total vaccinations
# 4. find the median percentage
# 5. create a new column called 'normalised_percentages' which duplicates the percentages column
# 6. normalise the normalised_percentages column so that any values greater than or equal to the median percentage = 1 and any lesser than = 0
#
#
# **Test output**:
#
# 1.
# 2.
# ```
# vaccine
# Johnson&Johnson        264839828
# Moderna               5548036383
# Oxford/AstraZeneca     539433203
# Pfizer/BioNTech       8690461304
# Sinovac                604660293
# Name: total_vaccinations, dtype: int64
# ```
# 3.
# ```
# 	location	date	vaccine	total_vaccinations	percentages
# 0	Chile	2020-12-24	Pfizer/BioNTech	420	0.000003
# 1	Chile	2020-12-25	Pfizer/BioNTech	5198	0.000033
# 2	Chile	2020-12-26	Pfizer/BioNTech	8338	0.000053
# 3	Chile	2020-12-27	Pfizer/BioNTech	8649	0.000055
# 4	Chile	2020-12-28	Pfizer/BioNTech	8649	0.000055
# ...	...	...	...	...	...
# 3291	United States	2021-05-01	Moderna	105947940	0.677095
# 3292	United States	2021-05-01	Pfizer/BioNTech	129013657	0.824504
# 3293	United States	2021-05-02	Johnson&Johnson	8374395	0.053519
# 3294	United States	2021-05-02	Moderna	106780082	0.682413
# 3295	United States	2021-05-02	Pfizer/BioNTech	130252779	0.832423
# 3296 rows × 5 columns
# ```
# 4. 0.0011110194374896931
# 5.
# 6.
# ```
# 	location	date	vaccine	total_vaccinations	percentages	normalise	normalised
# 0	Chile	2020-12-24	Pfizer/BioNTech	420	0.000003	0.000003	0
# 1	Chile	2020-12-25	Pfizer/BioNTech	5198	0.000033	0.000033	0
# 2	Chile	2020-12-26	Pfizer/BioNTech	8338	0.000053	0.000053	0
# 3	Chile	2020-12-27	Pfizer/BioNTech	8649	0.000055	0.000055	0
# 4	Chile	2020-12-28	Pfizer/BioNTech	8649	0.000055	0.000055	0
# ...	...	...	...	...	...	...	...
# 3291	United States	2021-05-01	Moderna	105947940	0.677095	0.677095	1
# 3292	United States	2021-05-01	Pfizer/BioNTech	129013657	0.824504	0.824504	1
# 3293	United States	2021-05-02	Johnson&Johnson	8374395	0.053519	0.053519	1
# 3294	United States	2021-05-02	Moderna	106780082	0.682413	0.682413	1
# 3295	United States	2021-05-02	Pfizer/BioNTech	130252779	0.832423	0.832423	1
# 3296 rows × 7 columns
# ```

# %%
# read data from 'by_manufacturer' sheet from Covid data
man_df = pd.read_excel(url, sheet_name = "by_manufacturer")
man_df.head()
# Out:
#   location       date          vaccine  total_vaccinations
# 0    Chile 2020-12-24  Pfizer/BioNTech                 420
# 1    Chile 2020-12-25  Pfizer/BioNTech                5198
# 2    Chile 2020-12-26  Pfizer/BioNTech                8338
# 3    Chile 2020-12-27  Pfizer/BioNTech                8649
# 4    Chile 2020-12-28  Pfizer/BioNTech                8649

# %%
# find the sum of total vaccinations for each manufacturer
man_df.groupby(["vaccine"])["total_vaccinations"].sum()
# Out:
# vaccine
# Johnson&Johnson        264839828
# Moderna               5548036383
# Oxford/AstraZeneca     539433203
# Pfizer/BioNTech       8690461304
# Sinovac                604660293
# Name: total_vaccinations, dtype: int64

# %%
# create a new column that has the total vaccinations as a percentage of the overall sum of total vaccinations
man_df['tot_vac_percent'] = man_df["total_vaccinations"] / man_df["total_vaccinations"].sum() * 100
man_df
# Out:
#            location       date          vaccine  total_vaccinations  \
# 0             Chile 2020-12-24  Pfizer/BioNTech                 420
# 1             Chile 2020-12-25  Pfizer/BioNTech                5198
# 2             Chile 2020-12-26  Pfizer/BioNTech                8338
# 3             Chile 2020-12-27  Pfizer/BioNTech                8649
# 4             Chile 2020-12-28  Pfizer/BioNTech                8649
# ...             ...        ...              ...                 ...
# 3291  United States 2021-05-01          Moderna           105947940
# 3292  United States 2021-05-01  Pfizer/BioNTech           129013657
# 3293  United States 2021-05-02  Johnson&Johnson             8374395
# 3294  United States 2021-05-02          Moderna           106780082
# 3295  United States 2021-05-02  Pfizer/BioNTech           130252779
#
#       tot_vac_percent
# 0            0.000003
# 1            0.000033
# 2            0.000053
# 3            0.000055
# 4            0.000055
# ...               ...
# 3291         0.677095
# 3292         0.824504
# 3293         0.053519
# 3294         0.682413
# 3295         0.832423
#
# [3296 rows x 5 columns]

# %%
# find the median percentage
med_per = man_df['tot_vac_percent'].median()
med_per
# Out:
# 0.0011110194374896931

# %%
# create a new column called 'normalised_percentages' which duplicates the percentages column
man_df['normalised_percentages'] = man_df['tot_vac_percent'].copy()
man_df
# Out:
#            location       date          vaccine  total_vaccinations  \
# 0             Chile 2020-12-24  Pfizer/BioNTech                 420
# 1             Chile 2020-12-25  Pfizer/BioNTech                5198
# 2             Chile 2020-12-26  Pfizer/BioNTech                8338
# 3             Chile 2020-12-27  Pfizer/BioNTech                8649
# 4             Chile 2020-12-28  Pfizer/BioNTech                8649
# ...             ...        ...              ...                 ...
# 3291  United States 2021-05-01          Moderna           105947940
# 3292  United States 2021-05-01  Pfizer/BioNTech           129013657
# 3293  United States 2021-05-02  Johnson&Johnson             8374395
# 3294  United States 2021-05-02          Moderna           106780082
# 3295  United States 2021-05-02  Pfizer/BioNTech           130252779
#
#       tot_vac_percent  normalised_percentages
# 0            0.000003                0.000003
# 1            0.000033                0.000033
# 2            0.000053                0.000053
# 3            0.000055                0.000055
# 4            0.000055                0.000055
# ...               ...                     ...
# 3291         0.677095                0.677095
# 3292         0.824504                0.824504
# 3293         0.053519                0.053519
# 3294         0.682413                0.682413
# 3295         0.832423                0.832423
#
# [3296 rows x 6 columns]

# %%
# normalise the normalised_percentages column so that any values greater than or equal to the median percentage = 1 and any lesser than = 0
def norm_per(df):
  if df['normalised_percentages'] >= med_per:
    return 1
  else:
    return 0

man_df['normalised_percentages'] = man_df.apply(norm_per, axis=1)

man_df
# Out:
#            location       date          vaccine  total_vaccinations  \
# 0             Chile 2020-12-24  Pfizer/BioNTech                 420
# 1             Chile 2020-12-25  Pfizer/BioNTech                5198
# 2             Chile 2020-12-26  Pfizer/BioNTech                8338
# 3             Chile 2020-12-27  Pfizer/BioNTech                8649
# 4             Chile 2020-12-28  Pfizer/BioNTech                8649
# ...             ...        ...              ...                 ...
# 3291  United States 2021-05-01          Moderna           105947940
# 3292  United States 2021-05-01  Pfizer/BioNTech           129013657
# 3293  United States 2021-05-02  Johnson&Johnson             8374395
# 3294  United States 2021-05-02          Moderna           106780082
# 3295  United States 2021-05-02  Pfizer/BioNTech           130252779
#
#       tot_vac_percent  normalised_percentages
# 0            0.000003                       0
# 1            0.000033                       0
# 2            0.000053                       0
# 3            0.000055                       0
# 4            0.000055                       0
# ...               ...                     ...
# 3291         0.677095                       1
# 3292         0.824504                       1
# 3293         0.053519                       1
# 3294         0.682413                       1
# 3295         0.832423                       1
#
# [3296 rows x 6 columns]
